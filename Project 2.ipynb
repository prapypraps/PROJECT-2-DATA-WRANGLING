# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df1=pd.read_csv('DS1.csv')

# %%
df1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df1.shape
# Out:
# (610, 10)

# %%
df1.axes[0]
# Out:
# RangeIndex(start=0, stop=610, step=1)

# %%
df1.axes[1]
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
df1.values
# Out:
# array([[1, '01-01-2011', 1, ..., 6, 1, 0.24],
#        [2, '01-01-2011', 1, ..., 6, 1, 0.22],
#        [3, '01-01-2011', 1, ..., 6, 1, 0.22],
#        ...,
#        [608, '28-01-2011', 1, ..., 5, 3, 0.18],
#        [609, '28-01-2011', 1, ..., 5, 3, 0.22],
#        [610, '28-01-2011', 1, ..., 5, 2, 0.2]], dtype=object)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=610, step=1)

# %%
df1.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
# 5        6  01-01-2011       1   0     1   5    False        6           2
# 6        7  01-01-2011       1   0     1   6    False        6           1
# 7        8  01-01-2011       1   0     1   7    False        6           1
# 8        9  01-01-2011       1   0     1   8    False        6           1
# 9       10  01-01-2011       1   0     1   9    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24
# 5  0.24
# 6  0.22
# 7  0.20
# 8  0.24
# 9  0.32

# %%
df1.tail(10)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 600      601  28-01-2011       1   0     1   6    False        5           2
# 601      602  28-01-2011       1   0     1   7    False        5           2
# 602      603  28-01-2011       1   0     1   8    False        5           2
# 603      604  28-01-2011       1   0     1   9    False        5           3
# 604      605  28-01-2011       1   0     1  10    False        5           3
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 600  0.18
# 601  0.16
# 602  0.16
# 603  0.18
# 604  0.18
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
df1.isnull()
# Out:
#      instant  dteday  season     yr   mnth     hr  holiday  weekday  \
# 0      False   False   False  False  False  False    False    False
# 1      False   False   False  False  False  False    False    False
# 2      False   False   False  False  False  False    False    False
# 3      False   False   False  False  False  False    False    False
# 4      False   False   False  False  False  False    False    False
# ..       ...     ...     ...    ...    ...    ...      ...      ...
# 605    False   False   False  False  False  False    False    False
# 606    False   False   False  False  False  False    False    False
# 607    False   False   False  False  False  False    False    False
# 608    False   False   False  False  False  False    False    False
# 609    False   False   False  False  False  False    False    False
#
#      weathersit   temp
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ...

# %%
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df2=pd.read_csv('DS2.csv')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.shape
# Out:
# (610, 8)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'instant', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df2.values
# Out:
# array([[0.000e+00, 1.000e+00, 2.879e-01, ..., 3.000e+00, 1.300e+01,
#         1.600e+01],
#        [1.000e+00, 2.000e+00, 2.727e-01, ..., 8.000e+00, 3.200e+01,
#         4.000e+01],
#        [2.000e+00, 3.000e+00, 2.727e-01, ..., 5.000e+00, 2.700e+01,
#         3.200e+01],
#        ...,
#        [6.070e+02, 6.080e+02, 2.121e-01, ..., 0.000e+00, 3.100e+01,
#         3.100e+01],
#        [6.080e+02, 6.090e+02, 2.727e-01, ..., 2.000e+00, 3.600e+01,
#         3.800e+01],
#        [6.090e+02, 6.100e+02, 2.576e-01, ..., 1.000e+00, 4.000e+01,
#         4.100e+01]])

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=610, step=1)

# %%
df2.head(10)
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81     0.0000       3          13   16
# 1           1        2  0.2727  0.80     0.0000       8          32   40
# 2           2        3  0.2727  0.80     0.0000       5          27   32
# 3           3        4  0.2879  0.75     0.0000       3          10   13
# 4           4        5  0.2879  0.75     0.0000       0           1    1
# 5           5        6  0.2576  0.75     0.0896       0           1    1
# 6           6        7  0.2727  0.80     0.0000       2           0    2
# 7           7        8  0.2576  0.86     0.0000       1           2    3
# 8           8        9     NaN  0.75     0.0000       1           7    8
# 9           9       10  0.3485  0.76     0.0000       8           6   14

# %%
df2.tail(10)
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 600         600      601  0.1970  0.80     0.1343       0          16   16
# 601         601      602  0.1970  0.86     0.0896       2          58   60
# 602         602      603  0.1970  0.86     0.0896       2         155  157
# 603         603      604  0.2121  0.86     0.0896       6          95  101
# 604         604      605  0.2121  0.86     0.1045       0          49   49
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
df2.isnull()
# Out:
#      Unnamed: 0  instant  atemp    hum  windspeed  casual  registered    cnt
# 0         False    False  False  False      False   False       False  False
# 1         False    False  False  False      False   False       False  False
# 2         False    False  False  False      False   False       False  False
# 3         False    False  False  False      False   False       False  False
# 4         False    False  False  False      False   False       False  False
# ..          ...      ...    ...    ...        ...     ...         ...    ...
# 605       False    False  False  False      False   False       False  False
# 606       False    False  False  False      False   False       False  False
# 607       False    False  False  False      False   False       False  False
# 608       False    False  False  False      False   False       False  False
# 609       False    False  False  False      False   False       False  False
#
# [610 rows x 8 columns]

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# combining data setrs 1 and 2
df3 = pd.concat([df1, df2], axis=1,)

# %%
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df3.shape
# Out:
# (610, 18)

# %%
df3.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'Unnamed: 0', 'instant', 'atemp', 'hum',
#        'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=610, step=1)

# %%
df3.ndim
# Out:
# 2

# %%
df3.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
# 5        6  01-01-2011       1   0     1   5    False        6           2
# 6        7  01-01-2011       1   0     1   6    False        6           1
# 7        8  01-01-2011       1   0     1   7    False        6           1
# 8        9  01-01-2011       1   0     1   8    False        6           1
# 9       10  01-01-2011       1   0     1   9    False        6           1
#
#    temp  Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df3.tail(10)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 600      601  28-01-2011       1   0     1   6    False        5           2
# 601      602  28-01-2011       1   0     1   7    False        5           2
# 602      603  28-01-2011       1   0     1   8    False        5           2
# 603      604  28-01-2011       1   0     1   9    False        5           3
# 604      605  28-01-2011       1   0     1  10    False        5           3
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp  Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  instant     610 non-null    int64
#  12  atemp       599 non-null    float64
#  13  hum         610 non-null    float64
#  14  windspeed   610 non-null    float64
#  15  casual      610 non-null    int64
#  16  registered  610 non-null    int64
#  17  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(12), object(1)
# ...

# %%
df3.isnull().sum() # misssing values
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df3.isnull().sum()/df3.shape[0] # percentage of missing values
# Out:
# instant       0.000000
# dteday        0.000000
# season        0.000000
# yr            0.000000
# mnth          0.000000
# hr            0.000000
# holiday       0.000000
# weekday       0.000000
# weathersit    0.000000
# temp          0.000000
# Unnamed: 0    0.000000
# instant       0.000000
# atemp         0.018033
# hum           0.000000
# windspeed     0.000000
# casual        0.000000
# registered    0.000000
# cnt           0.000000
# dtype: float64

# %%
df3.duplicated().sum() # finding duplicate values
# Out:
# 0

# %%
for i in df3.select_dtypes(include="object").columns: # Findsing garbage values
    print(df3[i].value_counts())
    print("****"*10)
# Out:
# dteday
# 01-01-2011    24
# 09-01-2011    24
# 21-01-2011    24
# 20-01-2011    24
# 17-01-2011    24
# 16-01-2011    24
# 13-01-2011    24
# 10-01-2011    24
# 15-01-2011    24
# 08-01-2011    24
# 05-01-2011    23
# 25-01-2011    23
# 24-01-2011    23
# 23-01-2011    23
# 22-01-2011    23
# 04-01-2011    23
# 19-01-2011    23
# 06-01-2011    23
# 02-01-2011    23
# 14-01-2011    23
# 07-01-2011    23
# 11-01-2011    22
# 03-01-2011    22
# 12-01-2011    22
# 26-01-2011    16
# 28-01-2011    15
# 18-01-2011    12
# 27-01-2011     8
# Name: count, dtype: int64
# ****************************************

# %%
df3.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp  Unnamed: 0     instant       atemp         hum   windspeed  \
# count  610.000000  610.000000  610.000000  599.000000  610.000000  610.000000
# mean     0.196885  304.500000  305.500000    0.199935    0.562475    0.204851
# ...

# %%
df3.describe().T
# Out:
#             count        mean         std   min       25%      50%       75%  \
# instant     610.0  305.500000  176.236111  1.00  153.2500  305.500  457.7500
# season      610.0    1.000000    0.000000  1.00    1.0000    1.000    1.0000
# yr          610.0    0.000000    0.000000  0.00    0.0000    0.000    0.0000
# mnth        610.0    1.000000    0.000000  1.00    1.0000    1.000    1.0000
# hr          610.0   11.795082    6.852107  0.00    6.0000   12.000   18.0000
# weekday     610.0    2.977049    2.054943  0.00    1.0000    3.000    5.0000
# weathersit  610.0    1.477049    0.643496  1.00    1.0000    1.000    2.0000
# temp        610.0    0.196885    0.081304  0.02    0.1600    0.200    0.2350
# Unnamed: 0  610.0  304.500000  176.236111  0.00  152.2500  304.500  456.7500
# instant     610.0  305.500000  176.236111  1.00  153.2500  305.500  457.7500
# atemp       599.0    0.199935    0.078836  0.00    0.1515    0.197    0.2424
# ...

# %%
df3.describe(include="object")
# Out:
#             dteday
# count          610
# unique          28
# top     01-01-2011
# freq            24

# %%
df3 = df3.drop(columns=['dteday','instant', 'yr', 'Unnamed: 0'])
df3
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0         1     1   0    False        6           1  0.24  0.2879  0.81
# 1         1     1   1    False        6           1  0.22  0.2727  0.80
# 2         1     1   2    False        6           1  0.22  0.2727  0.80
# 3         1     1   3    False        6           1  0.24  0.2879  0.75
# 4         1     1   4    False        6           1  0.24  0.2879  0.75
# ..      ...   ...  ..      ...      ...         ...   ...     ...   ...
# 605       1     1  11    False        5           3  0.18  0.2121  0.93
# 606       1     1  12    False        5           3  0.18  0.2121  0.93
# 607       1     1  13    False        5           3  0.18  0.2121  0.93
# 608       1     1  14    False        5           3  0.22  0.2727  0.80
# 609       1     1  15    False        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# ...

# %%
df3['atemp'] = df3['atemp'].fillna(df3['atemp'].median())

# %%
df3
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0         1     1   0    False        6           1  0.24  0.2879  0.81
# 1         1     1   1    False        6           1  0.22  0.2727  0.80
# 2         1     1   2    False        6           1  0.22  0.2727  0.80
# 3         1     1   3    False        6           1  0.24  0.2879  0.75
# 4         1     1   4    False        6           1  0.24  0.2879  0.75
# ..      ...   ...  ..      ...      ...         ...   ...     ...   ...
# 605       1     1  11    False        5           3  0.18  0.2121  0.93
# 606       1     1  12    False        5           3  0.18  0.2121  0.93
# 607       1     1  13    False        5           3  0.18  0.2121  0.93
# 608       1     1  14    False        5           3  0.22  0.2727  0.80
# 609       1     1  15    False        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# ...

# %%
df3.isnull().sum()
# Out:
# season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3['holiday'] = df3['holiday'].astype(int) # converting boolen to int

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      610 non-null    int64
#  1   mnth        610 non-null    int64
#  2   hr          610 non-null    int64
#  3   holiday     610 non-null    int32
#  4   weekday     610 non-null    int64
#  5   weathersit  610 non-null    int64
#  6   temp        610 non-null    float64
#  7   atemp       610 non-null    float64
#  8   hum         610 non-null    float64
#  9   windspeed   610 non-null    float64
#  10  casual      610 non-null    int64
#  11  registered  610 non-null    int64
#  12  cnt         610 non-null    int64
# dtypes: float64(4), int32(1), int64(8)
# memory usage: 59.7 KB

# %%
# Histogram to understaqnd distribution
ignore
for i in df3.select_dtypes(include='number').columns:
    sns.histplot(data=df3,x=i, bins=15, edgecolor='black')
    plt.show()

# %%
# using boxplot for outliers 
for i in df3.select_dtypes(include='number').columns:
    sns.boxplot(data=df3,x=i)
    plt.show()

# %%
df3.select_dtypes(include='number').columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp',
#        'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# scatter plot to see relationship
for i in ['season', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp',
       'atemp', 'hum', 'windspeed', 'casual', 'registered', ]:
    sns.scatterplot(data=df3,x=i,y='cnt')
    plt.show()

# %%
# correlation with heat map to interpret relationship

s=df3.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
skewness = df3.skew()
print(skewness)
# Out:
# season        0.000000
# mnth          0.000000
# hr           -0.072059
# holiday       4.750637
# weekday       0.026403
# weathersit    1.050244
# temp          0.665087
# atemp         0.562669
# hum           0.609553
# windspeed     0.339029
# casual        2.712869
# registered    1.428875
# cnt           1.243563
# dtype: float64

# %%
df3.hist(bins=15, edgecolor='black', grid=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # DATASET 3

# %%
df4=pd.read_csv('DS3.csv')

# %%
df4
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df4.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
# 5      625  29-01-2011       1   0     1   7    False        6           1
# 6      626  29-01-2011       1   0     1   8    False        6           1
# 7      627  29-01-2011       1   0     1   9    False        6           1
# 8      628  29-01-2011       1   0     1  10    False        6           2
# 9      629  29-01-2011       1   0     1  11    False        6           2
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# ...

# %%
df6=df4.tail(9)

# %%
df6
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 381      611  28-01-2011       1   0     1  16    False        5           1
# 382      612  28-01-2011       1   0     1  17    False        5           1
# 383      613  28-01-2011       1   0     1  18    False        5           1
# 384      614  28-01-2011       1   0     1  19    False        5           2
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 381  0.22  0.2727  0.80     0.0000      10          70   80
# 382  0.24  0.2424  0.75     0.1343       2         147  149
# ...

# %%
# Here we can see values are not in order
df4.tail(20)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 370      990  13-02-2011       1   0     2  21    False        0           1
# 371      991  13-02-2011       1   0     2  22    False        0           1
# 372      992  13-02-2011       1   0     2  23    False        0           1
# 373      993  14-02-2011       1   0     2   0    False        1           1
# 374      994  14-02-2011       1   0     2   1    False        1           1
# 375      995  14-02-2011       1   0     2   2    False        1           1
# 376      996  14-02-2011       1   0     2   3    False        1           1
# 377      997  14-02-2011       1   0     2   4    False        1           1
# 378      998  14-02-2011       1   0     2   5    False        1           1
# 379      999  14-02-2011       1   0     2   6    False        1           1
# 380     1000  14-02-2011       1   0     2   7    False        1           1
# ...

# %%
df5 = df4.drop([381 ,382,383,384,385,386,387,388,389])

# %%
df5
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 376      996  14-02-2011       1   0     2   3    False        1           1
# 377      997  14-02-2011       1   0     2   4    False        1           1
# 378      998  14-02-2011       1   0     2   5    False        1           1
# 379      999  14-02-2011       1   0     2   6    False        1           1
# 380     1000  14-02-2011       1   0     2   7    False        1           1
#
# ...

# %%
df5.shape
# Out:
# (381, 16)

# %%
df6.shape
# Out:
# (9, 16)

# %%
df5.ndim
# Out:
# 2

# %%
df6.ndim
# Out:
# 2

# %%
df5.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df6.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df5.values
# Out:
# array([[620, '29-01-2011', 1, ..., 0, 20, 20],
#        [621, '29-01-2011', 1, ..., 0, 15, 15],
#        [622, '29-01-2011', 1, ..., 3, 5, 8],
#        ...,
#        [998, '14-02-2011', 1, ..., 0, 3, 3],
#        [999, '14-02-2011', 1, ..., 1, 25, 26],
#        [1000, '14-02-2011', 1, ..., 2, 96, 98]], dtype=object)

# %%
df6.values
# Out:
# array([[611, '28-01-2011', 1, 0, 1, 16, False, 5, 1, 0.22, 0.2727, 0.8,
#         0.0, 10, 70, 80],
#        [612, '28-01-2011', 1, 0, 1, 17, False, 5, 1, 0.24, 0.2424, 0.75,
#         0.1343, 2, 147, 149],
#        [613, '28-01-2011', 1, 0, 1, 18, False, 5, 1, 0.24, 0.2273, 0.75,
#         0.194, 2, 107, 109],
#        [614, '28-01-2011', 1, 0, 1, 19, False, 5, 2, 0.24, 0.2424, 0.75,
#         0.1343, 5, 84, 89],
#        [615, '28-01-2011', 1, 0, 1, 20, False, 5, 2, 0.24, 0.2273, 0.7,
#         0.194, 1, 61, 62],
#        [616, '28-01-2011', 1, 0, 1, 21, False, 5, 2, 0.22, 0.2273, 0.75,
#         0.1343, 1, 57, 58],
#        [617, '28-01-2011', 1, 0, 1, 22, False, 5, 1, 0.24, 0.2121, 0.65,
#         0.3582, 0, 26, 26],
#        [618, '28-01-2011', 1, 0, 1, 23, False, 5, 1, 0.24, 0.2273, 0.6,
#         0.2239, 1, 22, 23],
#        [619, '29-01-2011', 1, 0, 1, 0, False, 6, 1, 0.22, 0.197, 0.64,
#         0.3582, 2, 26, 28]], dtype=object)

# %%
df5
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 376      996  14-02-2011       1   0     2   3    False        1           1
# 377      997  14-02-2011       1   0     2   4    False        1           1
# 378      998  14-02-2011       1   0     2   5    False        1           1
# 379      999  14-02-2011       1   0     2   6    False        1           1
# 380     1000  14-02-2011       1   0     2   7    False        1           1
#
# ...

# %%
df7= pd.concat([df6, df5], axis=0)

# %%
df7
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 381      611  28-01-2011       1   0     1  16    False        5           1
# 382      612  28-01-2011       1   0     1  17    False        5           1
# 383      613  28-01-2011       1   0     1  18    False        5           1
# 384      614  28-01-2011       1   0     1  19    False        5           2
# 385      615  28-01-2011       1   0     1  20    False        5           2
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 376      996  14-02-2011       1   0     2   3    False        1           1
# 377      997  14-02-2011       1   0     2   4    False        1           1
# 378      998  14-02-2011       1   0     2   5    False        1           1
# 379      999  14-02-2011       1   0     2   6    False        1           1
# 380     1000  14-02-2011       1   0     2   7    False        1           1
#
# ...

# %%
df7.shape
# Out:
# (390, 16)

# %%
df7 = df7.drop(columns=['dteday','instant', 'yr',])
df7
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 381       1     1  16    False        5           1  0.22  0.2727  0.80
# 382       1     1  17    False        5           1  0.24  0.2424  0.75
# 383       1     1  18    False        5           1  0.24  0.2273  0.75
# 384       1     1  19    False        5           2  0.24  0.2424  0.75
# 385       1     1  20    False        5           2  0.24  0.2273  0.70
# ..      ...   ...  ..      ...      ...         ...   ...     ...   ...
# 376       1     2   3    False        1           1  0.34  0.3182  0.46
# 377       1     2   4    False        1           1  0.32  0.3030  0.53
# 378       1     2   5    False        1           1  0.32  0.3030  0.53
# 379       1     2   6    False        1           1  0.34  0.3030  0.46
# 380       1     2   7    False        1           1  0.34  0.3030  0.46
#
#      windspeed  casual  registered  cnt
# 381     0.0000      10          70   80
# ...

# %%
df7.shape
# Out:
# (390, 13)

# %%
df7.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp',
#        'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df7.values
# Out:
# array([[1, 1, 16, ..., 10, 70, 80],
#        [1, 1, 17, ..., 2, 147, 149],
#        [1, 1, 18, ..., 2, 107, 109],
#        ...,
#        [1, 2, 5, ..., 0, 3, 3],
#        [1, 2, 6, ..., 1, 25, 26],
#        [1, 2, 7, ..., 2, 96, 98]], dtype=object)

# %%
df7.ndim
# Out:
# 2

# %%
df7.index
# Out:
# Index([381, 382, 383, 384, 385, 386, 387, 388, 389,   0,
#        ...
#        371, 372, 373, 374, 375, 376, 377, 378, 379, 380],
#       dtype='int64', length=390)

# %%
df7.head()
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 381       1     1  16    False        5           1  0.22  0.2727  0.80
# 382       1     1  17    False        5           1  0.24  0.2424  0.75
# 383       1     1  18    False        5           1  0.24  0.2273  0.75
# 384       1     1  19    False        5           2  0.24  0.2424  0.75
# 385       1     1  20    False        5           2  0.24  0.2273  0.70
#
#      windspeed  casual  registered  cnt
# 381     0.0000      10          70   80
# 382     0.1343       2         147  149
# 383     0.1940       2         107  109
# 384     0.1343       5          84   89
# 385     0.1940       1          61   62

# %%
df7.tail()
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 376       1     2   3    False        1           1  0.34  0.3182  0.46
# 377       1     2   4    False        1           1  0.32  0.3030  0.53
# 378       1     2   5    False        1           1  0.32  0.3030  0.53
# 379       1     2   6    False        1           1  0.34  0.3030  0.46
# 380       1     2   7    False        1           1  0.34  0.3030  0.46
#
#      windspeed  casual  registered  cnt
# 376     0.2239       1           1    2
# 377     0.2836       0           2    2
# 378     0.2836       0           3    3
# 379     0.2985       1          25   26
# 380     0.2985       2          96   98

# %%
df= pd.concat([df3,df7], axis=0)

# %%
df # here we can see index error
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0         1     1   0        0        6           1  0.24  0.2879  0.81
# 1         1     1   1        0        6           1  0.22  0.2727  0.80
# 2         1     1   2        0        6           1  0.22  0.2727  0.80
# 3         1     1   3        0        6           1  0.24  0.2879  0.75
# 4         1     1   4        0        6           1  0.24  0.2879  0.75
# ..      ...   ...  ..      ...      ...         ...   ...     ...   ...
# 376       1     2   3        0        1           1  0.34  0.3182  0.46
# 377       1     2   4        0        1           1  0.32  0.3030  0.53
# 378       1     2   5        0        1           1  0.32  0.3030  0.53
# 379       1     2   6        0        1           1  0.34  0.3030  0.46
# 380       1     2   7        0        1           1  0.34  0.3030  0.46
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# ...

# %%
df_reset = df.reset_index(drop=True) # correcting index error
df_reset
df=df_reset

# %%
df.head()
# Out:
#    season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0       1     1   0        0        6           1  0.24  0.2879  0.81
# 1       1     1   1        0        6           1  0.22  0.2727  0.80
# 2       1     1   2        0        6           1  0.22  0.2727  0.80
# 3       1     1   3        0        6           1  0.24  0.2879  0.75
# 4       1     1   4        0        6           1  0.24  0.2879  0.75
#
#    windspeed  casual  registered  cnt
# 0        0.0       3          13   16
# 1        0.0       8          32   40
# 2        0.0       5          27   32
# 3        0.0       3          10   13
# 4        0.0       0           1    1

# %%
df.tail()
# Out:
#      season  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 995       1     2   3        0        1           1  0.34  0.3182  0.46
# 996       1     2   4        0        1           1  0.32  0.3030  0.53
# 997       1     2   5        0        1           1  0.32  0.3030  0.53
# 998       1     2   6        0        1           1  0.34  0.3030  0.46
# 999       1     2   7        0        1           1  0.34  0.3030  0.46
#
#      windspeed  casual  registered  cnt
# 995     0.2239       1           1    2
# 996     0.2836       0           2    2
# 997     0.2836       0           3    3
# 998     0.2985       1          25   26
# 999     0.2985       2          96   98

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp',
#        'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.values
# Out:
# array([[ 1.,  1.,  0., ...,  3., 13., 16.],
#        [ 1.,  1.,  1., ...,  8., 32., 40.],
#        [ 1.,  1.,  2., ...,  5., 27., 32.],
#        ...,
#        [ 1.,  2.,  5., ...,  0.,  3.,  3.],
#        [ 1.,  2.,  6., ...,  1., 25., 26.],
#        [ 1.,  2.,  7., ...,  2., 96., 98.]])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      1000 non-null   int64
#  1   mnth        1000 non-null   int64
#  2   hr          1000 non-null   int64
#  3   holiday     1000 non-null   int32
#  4   weekday     1000 non-null   int64
#  5   weathersit  1000 non-null   int64
#  6   temp        1000 non-null   float64
#  7   atemp       1000 non-null   float64
#  8   hum         1000 non-null   float64
#  9   windspeed   1000 non-null   float64
#  10  casual      1000 non-null   int64
#  11  registered  1000 non-null   int64
#  12  cnt         1000 non-null   int64
# dtypes: float64(4), int32(1), int64(8)
# memory usage: 97.8 KB

# %%
df.isnull().sum()
# Out:
# season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.describe()
# Out:
#        season         mnth           hr      holiday      weekday  \
# count  1000.0  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.0     1.312000    11.753000     0.024000     2.982000
# std       0.0     0.463542     6.899101     0.153126     2.091423
# min       1.0     1.000000     0.000000     0.000000     0.000000
# 25%       1.0     1.000000     6.000000     0.000000     1.000000
# 50%       1.0     1.000000    12.000000     0.000000     3.000000
# 75%       1.0     2.000000    18.000000     0.000000     5.000000
# max       1.0     2.000000    23.000000     1.000000     6.000000
#
#         weathersit         temp        atemp          hum    windspeed  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.480000     0.205900     0.211793     0.582480     0.194931
# std       0.651171     0.078977     0.076295     0.187977     0.129126
# min       1.000000     0.020000     0.000000     0.210000     0.000000
# ...

# %%
df.describe().T
# Out:
#              count       mean        std   min      25%      50%      75%  \
# season      1000.0   1.000000   0.000000  1.00   1.0000   1.0000   1.0000
# mnth        1000.0   1.312000   0.463542  1.00   1.0000   1.0000   2.0000
# hr          1000.0  11.753000   6.899101  0.00   6.0000  12.0000  18.0000
# holiday     1000.0   0.024000   0.153126  0.00   0.0000   0.0000   0.0000
# weekday     1000.0   2.982000   2.091423  0.00   1.0000   3.0000   5.0000
# weathersit  1000.0   1.480000   0.651171  1.00   1.0000   1.0000   2.0000
# temp        1000.0   0.205900   0.078977  0.02   0.1600   0.2000   0.2400
# atemp       1000.0   0.211793   0.076295  0.00   0.1667   0.2121   0.2576
# hum         1000.0   0.582480   0.187977  0.21   0.4400   0.5500   0.7000
# windspeed   1000.0   0.194931   0.129126  0.00   0.1045   0.1642   0.2836
# casual      1000.0   4.921000   7.643899  0.00   0.0000   3.0000   6.0000
# registered  1000.0  53.383000  47.893968  0.00  15.0000  46.0000  74.0000
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# now plotting histogram
for i in df.select_dtypes(include='number').columns:
    sns.histplot(data=df,x=i, bins=15, edgecolor='black')
    plt.show()

# %%
# using scatter plot
for i in ['season', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp',
       'atemp', 'hum', 'windspeed', 'casual', 'registered', ]:
    sns.scatterplot(data=df,x=i,y='cnt')
    plt.show()

# %%
# Checking outliers

# %%
for i in df.select_dtypes(include='number').columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
# working on outliers
# We will do outlier treatment for temp , atemp , hum , windspeed

def wisker (col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
wisker(df['temp'])
# Out:
# (0.04000000000000002, 0.36)

# %%
for i in ['temp','atemp','hum','windspeed']:
    lw,uw=wisker(df[i])
    df[i]=np.where(df[i]<lw,lw,df[i])
    df[i]=np.where(df[i]>uw,uw,df[i])

# %%
for i in ['temp','atemp','hum','windspeed']: # checking wether it is resolved or now
    sns.boxplot(df[i])
    plt.show()

# %%
# correlation with heat map to interpret relationship

s=df.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
skewness = df3.skew()
print(skewness)
# Out:
# season        0.000000
# mnth          0.000000
# hr           -0.072059
# holiday       4.750637
# weekday       0.026403
# weathersit    1.050244
# temp          0.665087
# atemp         0.562669
# hum           0.609553
# windspeed     0.339029
# casual        2.712869
# registered    1.428875
# cnt           1.243563
# dtype: float64

# %%
df3.hist(bins=15, edgecolor='black', grid=False)
plt.tight_layout()
plt.show()
